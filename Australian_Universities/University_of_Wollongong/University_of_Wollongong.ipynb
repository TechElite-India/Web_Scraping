# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

# %%
res1=requests.get('https://coursefinder.uow.edu.au/index.html')
soup1=bs4.BeautifulSoup(res1.text,'lxml')

# %%
s1=soup1.select('.study-options')
for i in s1[0].select('a'):
    print(str(i.text)[1:])
    print('https://coursefinder.uow.edu.au'+i.get('href'))
# Out:
# Arts & Humanities
# https://coursefinder.uow.edu.au/arts-humanities/index.html
# Business
# https://coursefinder.uow.edu.au/business/index.html
# Communications & Media
# https://coursefinder.uow.edu.au/communications-media/index.html
# Creative Arts
# https://coursefinder.uow.edu.au/creative-arts/index.html
# Education
# https://coursefinder.uow.edu.au/education/index.html
# Engineering
# https://coursefinder.uow.edu.au/engineering/index.html
# Geography
# https://coursefinder.uow.edu.au/geography/index.html
# Health & Medicine
# https://coursefinder.uow.edu.au/health-medicine/index.html
# Information & Communication Technology
# https://coursefinder.uow.edu.au/information-communication-technology/index.html
# International Studies
# https://coursefinder.uow.edu.au/international-studies/index.html
# Law
# https://coursefinder.uow.edu.au/law/index.html
# Mathematics & Statistics
# https://coursefinder.uow.edu.au/mathematics-statistics/index.html
# Physics
# ...

# %%
res2=requests.get('https://coursefinder.uow.edu.au/arts-humanities/index.html')
soup2=bs4.BeautifulSoup(res2.text,'lxml')

# %%
s2=soup2.select('.two-column')
for j in range(len(s2)):
    for k in s2[j].select('a'):
        print(k.text)
        print(k.get('href'))
# Out:
# Bachelor of Arts
# http://coursefinder.uow.edu.au/information/index.html?course=bachelor-of-arts
# Bachelor of Arts (Archaeology & Ancient History)
# https://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-archaeology-ancient-history
# Bachelor of Arts | Bachelor of Communication & Media
# https://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-bachelor-communication-media
# Bachelor of Arts | Bachelor of Communication (Dean's Scholar)
# https://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-bachelor-communication-media-deans-scholar
# Bachelor of Arts (Community, Culture & Environment)
# http://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-community-culture-environment
# Bachelor of Arts (Creative Writing)
# http://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-creative-writing
# Bachelor of Arts (Dean's Scholar)
# ...

# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

s1=soup1.select('.study-options')
for i in s1[0].select('a'):
    res2=requests.get('https://coursefinder.uow.edu.au'+i.get('href'))
    soup2=bs4.BeautifulSoup(res2.text,'lxml')
    s2=soup2.select('.two-column')
    for j in range(len(s2)):
        for k in s2[j].select('a'):
            list.append([k.text,'',str(i.text)[1:],'','University of Wollongong',k.get('href')])
            
list
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Bachelor of Arts',
#   '',
#   'Arts & Humanities',
#   '',
#   'University of Wollongong',
#   'http://coursefinder.uow.edu.au/information/index.html?course=bachelor-of-arts'],
#  ['Bachelor of Arts (Archaeology & Ancient History)',
#   '',
#   'Arts & Humanities',
#   '',
#   'University of Wollongong',
#   'https://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-archaeology-ancient-history'],
#  ['Bachelor of Arts | Bachelor of Communication & Media',
#   '',
#   'Arts & Humanities',
#   '',
#   'University of Wollongong',
#   'https://coursefinder.uow.edu.au/information/index.html?course=bachelor-arts-bachelor-communication-media'],
#  ["Bachelor of Arts | Bachelor of Communication (Dean's Scholar)\xa0",
#   '',
#   'Arts & Humanities',
#   '',
#   'University of Wollongong',
# ...

# %%
len(list)
# Out:
# 495

# %%
with open('University_of_Wollongong.csv','w',newline="") as file:
    write=csv.writer(file)
    for row in list:
        write.writerow(row)
