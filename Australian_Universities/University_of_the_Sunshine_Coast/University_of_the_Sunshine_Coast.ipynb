# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

# %%
res1=requests.get('https://www.usc.edu.au/time-to-shine/find-your-program/arts-languages-and-international-studies')
soup1=bs4.BeautifulSoup(res1.text,'lxml')

# %%
s1=soup1.select('.col-md-6  ')
for i in range(len(s1)):
    for j in s1[i].select('a'):
        print(j.text)
        print('https://www.usc.edu.au'+j.get('href'))
# Out:
# Bachelor of Arts
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-arts
# Bachelor of International Studies
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-international-studies
# Bachelor of Social Science
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-social-science
# Bachelor of Arts (Honours)
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-arts-honours
# Bachelor of Social Science (Honours)
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-social-science-honours
# Bachelor of Arts / Bachelor of Business
# https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-arts-bachelor-of-business
# Bachelor of Arts / Bachelor of Science
# ...

# %%
res2=requests.get('https://www.usc.edu.au/learn/courses-and-programs')
soup2=bs4.BeautifulSoup(res2.text,'lxml')

# %%
s2=soup2.select('.col-md-12  ')
for k in s2[0].select('a'):
    print(k.text)
    print('https://www.usc.edu.au'+k.get('href'))
# Out:
# Arts, languages and international studies
# https://www.usc.edu.au/time-to-shine/find-your-program/arts-languages-and-international-studies
# Business, IT, tourism and events
# https://www.usc.edu.au/time-to-shine/find-your-program/business-it-tourism-and-events
# Communication and creative industries
# https://www.usc.edu.au/time-to-shine/find-your-program/communication-and-creative-industries
# Education
# https://www.usc.edu.au/time-to-shine/find-your-program/education
# Environmental studies
# https://www.usc.edu.au/time-to-shine/find-your-program/environmental-studies
# Medical and health sciences
# https://www.usc.edu.au/time-to-shine/find-your-program/medical-and-health-sciences
# Law and criminology
# https://www.usc.edu.au/time-to-shine/find-your-program/law-and-criminology
# Nursing, midwifery and paramedicine
# https://www.usc.edu.au/time-to-shine/find-your-program/nursing-midwifery-and-paramedicine
# Psychology and social sciences
# ...

# %%
res3=requests.get('https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees')
soup3=bs4.BeautifulSoup(res3.text,'lxml')

# %%
s3=soup3.select('.archetype-studyareas')
s33=s3[0].select('uib-accordion-heading')
for l in range(len(s33)):
    print(str(s33[l].text)[30:-1])
# Out:
# Business, IT and tourism
# Creative industries, design and communication
# Education
# Engineering and science
# Health, nursing and sport sciences
# Humanities, psychology and social sciences
# Law and criminology

# %%
s333=s3[0].select('ul')
for m in range(len(s333)):
    print(str(s33[l].text)[30:-1])
    for n in s333[m].select('a'):
        print(n.text)
        print('https://www.usc.edu.au'+n.get('href'))
# Out:
# Law and criminology
# Doctor of Philosophy
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/doctor-of-philosophy
# Executive Master of Business Administration
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/executive-master-of-business-administration
# Graduate Certificate in Business Administration
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/graduate-certificate-in-business-administration
# Graduate Certificate in Business Research
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/graduate-certificate-in-business-research
# Graduate Certificate in Cyber Investigations
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/graduate-certificate-in-cyber-investigations
# Graduate Certificate in Cyber Security
# https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/graduate-certificate-in-cyber-security
# Graduate Certificate in Management
# ...

# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

list1=[]

res2=requests.get('https://www.usc.edu.au/learn/courses-and-programs')
soup2=bs4.BeautifulSoup(res2.text,'lxml')
s2=soup2.select('.col-md-12  ')
for k in s2[0].select('a'):
    res1=requests.get('https://www.usc.edu.au'+k.get('href'))
    soup1=bs4.BeautifulSoup(res1.text,'lxml')
    s1=soup1.select('.col-md-6  ')
    for i in range(len(s1)):
        for j in s1[i].select('a'):
            list.append([j.text,'Undergraduate',k.text,'','University of the Sunshine Coast','https://www.usc.edu.au'+j.get('href')])
    
res3=requests.get('https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees')
soup3=bs4.BeautifulSoup(res3.text,'lxml')
s3=soup3.select('.archetype-studyareas')
s33=s3[0].select('uib-accordion-heading')
s333=s3[0].select('ul')
for m in range(len(s333)):
    for n in s333[m].select('a'):
        list1.append([n.text,'Postgraduate',str(s33[l].text)[30:-1],'','University of the Sunshine Coast','https://www.usc.edu.au'+n.get('href')])

# %%
list
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Bachelor of Arts',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-arts'],
#  ['Bachelor of International Studies',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-international-studies'],
#  ['Bachelor of Social Science',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-social-science'],
#  ['Bachelor of Arts (Honours)',
#   'Undergraduate',
# ...

# %%
len(list)
# Out:
# 119

# %%
list1
# Out:
# [['Doctor of Philosophy',
#   'Postgraduate',
#   'Law and criminology ',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/doctor-of-philosophy'],
#  ['Executive Master of Business Administration',
#   'Postgraduate',
#   'Law and criminology ',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/executive-master-of-business-administration'],
#  ['Graduate Certificate in Business Administration',
#   'Postgraduate',
#   'Law and criminology ',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/postgraduate-degrees/graduate-certificate-in-business-administration'],
#  ['Graduate Certificate in Business Research',
#   'Postgraduate',
#   'Law and criminology ',
#   '',
#   'University of the Sunshine Coast',
# ...

# %%
len(list1)
# Out:
# 55

# %%
list2=list+list1
list2
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Bachelor of Arts',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-arts'],
#  ['Bachelor of International Studies',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-international-studies'],
#  ['Bachelor of Social Science',
#   'Undergraduate',
#   'Arts, languages and international studies',
#   '',
#   'University of the Sunshine Coast',
#   'https://www.usc.edu.au/learn/courses-and-programs/bachelor-degrees-undergraduate-programs/bachelor-of-social-science'],
#  ['Bachelor of Arts (Honours)',
#   'Undergraduate',
# ...

# %%
len(list2)
# Out:
# 174

# %%
with open('University_of_the_Sunshine_Coast.csv','w',newline="") as file:
    write=csv.writer(file)
    for row in list2:
        write.writerow(row)
