# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

res=requests.get('https://www.jcu.edu.au/courses-and-study')
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
s=soup.select('.megamenu__level-3-item')
for i in range(26):
    print(str(s[i].a.text)[85:-80])
    print(s[i].a.get('href'))
# Out:
# Arts and Social Sciences
# https://www.jcu.edu.au/courses-and-study/study-areas/arts-and-social-sciences
# Biomedical Sciences
# https://www.jcu.edu.au/courses-and-study/study-areas/biomedical-sciences
# Business
# https://www.jcu.edu.au/courses-and-study/study-areas/business
# Dentistry
# https://www.jcu.edu.au/courses-and-study/study-areas/dentistry
# Education
# https://www.jcu.edu.au/courses-and-study/study-areas/education
# Engineering
# https://www.jcu.edu.au/courses-and-study/study-areas/engineering
# Environmental Management
# https://www.jcu.edu.au/courses-and-study/study-areas/environmental-management
# Geoscience
# https://www.jcu.edu.au/courses-and-study/study-areas/geoscience
# Health Studies
# https://www.jcu.edu.au/courses-and-study/study-areas/health-studies
# Information Technology
# https://www.jcu.edu.au/courses-and-study/study-areas/information-technology
# Law
# https://www.jcu.edu.au/courses-and-study/study-areas/law
# Marine Science
# ...

# %%
lk=['Diploma','Undergraduate','Postgraduate']

# %%
res=requests.get('https://www.jcu.edu.au/courses-and-study/study-areas/arts-and-social-sciences')
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
s=soup.select('.resp-tabs-container')
s1=s[0].select('div')
s2=s1[0].select('div')
s2[0]
# Out:
# <div class="columns is-multiline"><div class="column is-half">Diploma<br/><a href="https://www.jcu.edu.au/courses-and-study/courses/diploma-of-higher-education-in-general-studies">Diploma of Higher Education, majoring in General Studies</a></div><div class="column is-half">Diploma<br/><a href="https://www.jcu.edu.au/courses-and-study/courses/diploma-of-higher-education-in-society-and-culture">Diploma of Higher Education, majoring in Society and Culture</a></div></div>

# %%
len(s2)
# Out:
# 3

# %%
res3=requests.get('https://www.jcu.edu.au/courses-and-study/courses/diploma-of-higher-education-in-health')
soup3=bs4.BeautifulSoup(res3.text,'lxml')

# %%
s=soup3.select('.coursedetails__intro')
print(s[0].text)
# Out:
# This course provides you with the basic skills and knowledge in a range of health-related fields and offers a pathway to degree level study. JCU Diplomas are designed to help you develop the necessary skills to be a successful university student. On successful completion of the Diploma, you can continue into a Bachelor degree program, and you may receive credit for successfully completed subjects.

# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

res1=requests.get('https://www.jcu.edu.au/courses-and-study')
soup1=bs4.BeautifulSoup(res1.text,'lxml')
s1=soup1.select('.megamenu__level-3-item')
for j in range(26,31):
    res2=requests.get(s1[j].a.get('href'))
    soup2=bs4.BeautifulSoup(res2.text,'lxml')
    s2=soup2.select('.course__title')
    for k in range(len(s2)):
        res3=requests.get(s2[k].a.get('href'))
        soup3=bs4.BeautifulSoup(res3.text,'lxml')
        s3=soup3.select('.coursedetails__intro')
        if(len(s3)!=0):
            list.append([s2[k].a.text,str(s1[j].a.text)[85:-80],'',s3[0].text,'James Cook University',s2[k].a.get('href')])
        else:
            list.append([s2[k].a.text,str(s1[j].a.text)[85:-80],'','','James Cook University',s2[k].a.get('href')])
list
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Diploma of Higher Education (Business) ',
#   'Undergraduate',
#   '',
#   'The course provides students eligible to enrol in the Bachelor of Business the opportunity to undertake a recognised business qualification of one-year full time duration. On successful completion you will graduate with the Diploma of Higher Education in Business, and have the option of entering the second year of the Bachelor of Business.',
#   'James Cook University',
#   'https://www.jcu.edu.au/courses-and-study/courses/diploma-of-higher-education-in-business'],
#  ['Diploma of Higher Education, majoring in Business Studies ',
#   'Undergraduate',
#   '',
# ...

# %%
len(list)
# Out:
# 199

# %%
list
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Diploma of Higher Education (Business) ',
#   'Undergraduate',
#   '',
#   'The course provides students eligible to enrol in the Bachelor of Business the opportunity to undertake a recognised business qualification of one-year full time duration. On successful completion you will graduate with the Diploma of Higher Education in Business, and have the option of entering the second year of the Bachelor of Business.',
#   'James Cook University',
#   'https://www.jcu.edu.au/courses-and-study/courses/diploma-of-higher-education-in-business'],
#  ['Diploma of Higher Education, majoring in Business Studies ',
#   'Undergraduate',
#   '',
# ...

# %%
with open('James_Cook_University.csv','w',encoding="utf-8",newline="") as file:
    write=csv.writer(file)
    for row in list:
        write.writerow(row)

# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

res=requests.get('https://www.jcu.edu.au/courses-and-study')
soup=bs4.BeautifulSoup(res.text,'lxml')

s=soup.select('.megamenu__level-3-item')
for i in range(26):                     
    res1=requests.get(s[i].a.get('href'))
    soup1=bs4.BeautifulSoup(res1.text,'lxml')
    s1=soup1.select('.megamenu__level-3-item')
    for j in range(26,31):
        res2=requests.get(s1[j].a.get('href'))
        soup2=bs4.BeautifulSoup(res2.text,'lxml')
        s2=soup2.select('.course__title')
        for k in range(len(s2)):
            res3=requests.get(s2[k].a.get('href'))
            soup3=bs4.BeautifulSoup(res3.text,'lxml')
            s3=soup3.select('.coursedetails__intro')
            if(len(s3)!=0):
                list.append([s2[k].a.text,str(s1[j].a.text)[85:-80],str(s[i].a.text)[85:-80],s3[0].text,'James Cook University',s2[k].a.get('href')])
            else:
                list.append([s2[k].a.text,str(s1[j].a.text)[85:-80],str(s[i].a.text)[85:-80],'','James Cook University',s2[k].a.get('href')])
list
