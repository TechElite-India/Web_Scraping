# %%
import requests
import bs4
import csv

list=[]
lis_h=['Course_Name','Course_Level','Course_Type','Cource_Description','University_Name','Link']
list.append(lis_h)

# %%
import pandas as pd
df1=pd.read_csv('All Postgraduate Units of Study - 2019 Academic Year Availability.csv')
df1.head()
# Out:
#                    Faculty                          Area of Study  \
# 0  Architecture and Design  Architectural and Design Science (PG)
# 1  Architecture and Design  Architectural and Design Science (PG)
# 2  Architecture and Design  Architectural and Design Science (PG)
# 3  Architecture and Design  Architectural and Design Science (PG)
# 4  Architecture and Design  Architectural and Design Science (PG)
#
#   Area of Study Code Level     Offered Unit Code  \
# 0               ARCH    PG  Semester 2  ARCH9028
# 1               ARCH    PG  Semester 2  ARCH9063
# 2               ARCH    PG  Semester 1  ARCH9074
# 3               ARCH    PG  Semester 1  ARCH9075
# 4               ARCH    PG  Semester 2  ARCH9080
#
#                              Unit Name  \
# 0   Conservation Methods and Practices
# 1                     Urban Morphology
# 2  Principles of Heritage Conservation
# 3           New Design in Old Settings
# 4   Urban Ecology, Design and Planning
#
# ...

# %%
df2=pd.read_csv('All Undergraduate Units of Study - 2019 Academic Year Availability.csv')
df2.head()
# Out:
#                    Faculty        Area of Study Area of Study Code Level  \
# 0  Architecture and Design  Design and Planning               BADP    UG
# 1  Architecture and Design  Design and Planning               BADP    UG
# 2  Architecture and Design  Design and Planning               BADP    UG
# 3  Architecture and Design  Design and Planning               BADP    UG
# 4  Architecture and Design  Design and Planning               BADP    UG
#
#       Offered Unit Code                  Unit Name  \
# 0  Semester 2  BADP1001         Empirical Thinking
# 1  Semester 2  BADP2001   Algorithmic Architecture
# 2  Semester 1  BADP2002  City Form and Development
# 3  Semester 1  BADP2003            Light and Sound
# 4  Semester 2  BADP2004      Building Technologies
#
#                                            More Info  \
# 0  https://sydney.edu.au/courses/units-of-study/2...
# 1  https://sydney.edu.au/courses/units-of-study/2...
# ...

# %%
len(df1)
# Out:
# 640

# %%
len(df2)
# Out:
# 2118

# %%
for i in range(len(df1)):
    list.append([df1.iloc[i][6],'Postgraduate',df1.iloc[i][1],'','University of Sydney',df1.iloc[i][7]])

# %%
len(list)
# Out:
# 641

# %%
list
# Out:
# [['Course_Name',
#   'Course_Level',
#   'Course_Type',
#   'Cource_Description',
#   'University_Name',
#   'Link'],
#  ['Conservation Methods and Practices',
#   'Postgraduate',
#   'Architectural and Design Science (PG)',
#   '',
#   'University of Sydney',
#   'https://sydney.edu.au/courses/units-of-study/2019/arch/arch9028.html'],
#  ['Urban Morphology',
#   'Postgraduate',
#   'Architectural and Design Science (PG)',
#   '',
#   'University of Sydney',
#   'https://sydney.edu.au/courses/units-of-study/2019/arch/arch9063.html'],
#  ['Principles of Heritage Conservation',
#   'Postgraduate',
#   'Architectural and Design Science (PG)',
#   '',
#   'University of Sydney',
#   'https://sydney.edu.au/courses/units-of-study/2019/arch/arch9074.html'],
#  ['New Design in Old Settings',
#   'Postgraduate',
#   'Architectural and Design Science (PG)',
#   '',
#   'University of Sydney',
#   'https://sydney.edu.au/courses/units-of-study/2019/arch/arch9075.html'],
# ...

# %%
for i in range(len(df2)):
    list.append([df2.iloc[i][6],'Undergraduate',df2.iloc[i][1],'','University of Sydney',df2.iloc[i][7]])

# %%
with open('University_of_Sydney.csv','w',newline="") as file:
    write=csv.writer(file)
    for row in list:
        write.writerow(row)
